# %% [markdown]
# <font size="6">Functional component</font>

# %%
# --------------Footer.css-----------------
.title{
    color: blueviolet;
    font-size: 20px;
}

# -------------Footer.js -----------------

import "./Footer.css" --------->

function Footer(){
    return(
        <div class="title">
            footer
        </div>
    )
}

export default Footer


# -----------------App.js-------------------------

import logo from './logo.svg';
import Footer from './Footer';
import './App.css';

function App() {
  return (
    <div >
      <p>salam</p>
      <Footer></Footer>------------>
    #   <Footer/> ----------------->
    </div>
  );
}

export default App;
# OR
export default function App() {
  return (
  );
}

# %% [markdown]
# <font size="6">Class component</font>

# %%
# `User.js`
import React, { Component } from 'react'

export default class User extends Component {
    render(){
        return(
            <div>
                    <h1>ShM</h1>
            </div>
        )
    }
}
# ------------
# `App.js`
# ------------
import React, {Component} from 'react'
import User from './user/User'

class App extends Component {
    render(){
        return(
            <div>
                <h1>Hi</h1>
                <User>Hi</User>
                <User>Hi</User>
                <User>Hi</User>
            </div>
        )
    }
}
""" ما میتونیم به کامپوننت کلاس رو هم روی کامپوننت فانکشن جایگذاری کنیم """

# %% [markdown]
# <font size=5>props</font>

# %%
# `Users.js`
import React from 'react'

export defualt function User(props){
    
    console.log(props) //{name:'ShM'}
    
    return(
        <div>
            <h1>Amin</h1> ---> مستقیم نشون میده
            <h1>Hello,{props.name}, Your age:{props.age}</h1> ---> تمامی داده های فایل آپ رو نشون میده تو صفحه
        </div>
    )
}


# ------------
# `App.js`
# ------------

import React from 'react'
import User from './users/User'

function App (){
    return(
        <div>
            <User name="ShM" age={23} ></User> --->هر یک از تگ های یوزر یک بار فایل یوزر اجرا و لاگ گرفته میشود
            <User name="Moahammad" age={62}></User>
            <User name="Elvin" age={3}></User>
        </div>
    )
}

export defualt App

# %% [markdown]
# Condition in Props

# %%
# Boxes.js
# ------

function Boxes(props){
    console.log(props);
    
    if (props.count > 0 ){
        return(
            <div className="boxes">
                <div className="box">
                    <div className="box_img">
                    <img src={props.image} />
                    </div>
    
                    <div className="box_content">
                        <h2 className="title">{props.title}</h2>
                        <span className="price">{props.price}$</span>
                        <p className="dicription">Lorem ipsum dolor sit, amet consectetur adipisicing elit. Blanditiis quo recusandae fugiat rem quibusdam ipsam autem vero totam </p>
                    </div>
                    <a href="#" className="link">Add To Card</a>
                </div>
            </div>
        )
        return null
    }
}

# ------------
# `App.js`
# ------------

function App() {
  return (
    <div className='Boxes_app'>
        <Boxes title="Asus" price={220} count={0} image="./images/1.png"></Boxes>
        <Boxes title="Mac" price={420} count={10}  image="./images/2.png"></Boxes>
        <Boxes title="Lenovo" price={320} count={5}  image="./images/3.webp"></Boxes>
    </div>
  );
}

# %% [markdown]
# Condition in Props(better way)
# spread-in-props

# %%
function Boxes(props){
    console.log(props);
    return(
        props.count > 0 && 
            <div className="boxes">
                <div className="box">
                    <div className="box_img">
                    <img src={props.image} />
                    </div>
    
                    <div className="box_content">
                        <h2 className="title">{props.title}</h2>
                        <span className="price">{props.price}$</span>
                        <p className="dicription">Lorem ipsum dolor sit, amet consectetur adipisicing elit. Blanditiis quo recusandae fugiat rem quibusdam ipsam autem vero totam </p>
                    </div>
                    <a href="#" className="link">Add To Card</a>
                </div>
            </div>
        )
}


# ---App.js---


function App() {
  const allProducts = [
    {title:"Asus" , price:220 , image:"./images/1.png" , count: 10  },
    {title:"Mac" , price:420 , image:"./images/2.png" , count:10  },
    {title:"Lenovo" , price:320 , image:"./images/3.webp" , count:0  }
  ] 
  return (
    <div className='Boxes_app'>
          <Boxes {...allProducts[0]} />
          <Boxes {...allProducts[1]}/>
          <Boxes {...allProducts[2]} />
    </div>
  );
}

# %% [markdown]
# props-rename

# %%
<!-- اگر کاربر عکسی را ارسال نکرده باشد پیش فرض را در آن قرار بدیهیم -->
function Boxes({title:productBox , image = "images/null.jpg" , price ,count}){   //=========>second way
    #  let {title , image , price ,count} = props  ====> first way
    let title = "Product"

    return(
        count > 0 && 
            <div className="boxes">
                <h1>{title}</h1>
                <div className="box">
                    <div className="box_img">
                    <img src={image} />
                    </div>
    
                    <div className="box_content">
                        <h2 className="title">{productBox}</h2>
                        <span className="price">{price}$</span>
                        <p className="dicription">Lorem ipsum dolor sit, amet consectetur adipisicing elit. Blanditiis quo recusandae fugiat rem quibusdam ipsam autem vero totam </p>
                    </div>
                    <a href="#" className="link">Add To Card</a>
                </div>
            </div>
        )
}
export default Boxes

# %% [markdown]
# 1.Props with Component(mini Modal project)

# %%
// import React from 'react'
import './Modal.css'
import React,{Component} from 'react'


export default class Modal extends Component{
    render(){
        # console.log(this.props);
        return(
                <div className="Modal">
                    {this.props.children}
                </div>
        )
    }
}

# -----------OR----------------

 ###Functional Modal#####

function Modal({children}){  

    return(
            <div className="Modal">

                {children}
            </div>
        )
}

# ------------App.js-------------------------

 function Modal({children}){  

     return(
            <div className="Modal">
                <div className="second_section">
                      {children}
                        <ul className="ul_modal">
                            <li>Yes</li>
                            <li>No</li>
                        </ul>
                </div>
            </div>
         )
 }

export default App;

# -----------

export default function App(){
  const allProuduct = [
    {title:"ShM",age:20},
    {title:"ShM",age:25},
    {title:"ShM",age:5}
  ]
  return(
    <div>
          <User {...allProuduct[0]}>45564564</User>
          <User {...allProuduct[1]}></User>
          <User {...allProuduct[2]}></User>
    </div>
  )
}

# %% [markdown]
# 2.Props with Component(mini Modal project)

# %%
function App() {
  return (
    <div className="Boxes_app">
      <Modal>

      </Modal>
    </div>
  );
}

export default App;



// ---------------Modal Functional------------

export default function Modal({title="you want Delete?"}){  

  return(
          <div className="Modal">
              <div className="second_section">
                    <p className='title'>{title}</p>
                      <ul className="ul_modal">
                          <li>Yes</li>
                          <li>No</li>
                      </ul>
              </div>
          </div>
      )
}
// ---------------Modal Functional------------

// --------------Modal Component -------------------



export default class Modal extends Component{
    render(){
        return(

                <div className="Modal">
                    <div className="second_section">
                        <p className="title">{this.props.message}</p>
                        <ul className="ul_modal">
                            <li>Yes</li>
                            <li>No</li>
                         </ul>
                    </div>
                </div>
        )
    }
}

Modal.defaultProps = {
    message: 'You want to Delete?'
}

# %% [markdown]
# <font size=5>npm i prop-types<font>

# %%
// ----------Number ------------------
# import propTypes  from 'prop-types'
// export default class Modal extends Component{
//     render(){
//         return(

//                 <div className="Modal">
//                     <div className="second_section">
//                         <p className="title">{this.props.message}</p>
//                         <ul className="ul_modal">
//                             <li>Yes</li>
//                             <li>No</li>
//                          </ul>
//                     </div>
//                 </div>
//         )
//     }
// }

// Modal.defaultProps = {
    // message: 'You want to Delete?' error beause its string type
//     message:2
// }

// Modal.propTypes = {
//     message: propTypes.number
// }

// -----------------oneOfType----------------


export default class Modal extends Component{
    render(){
        return(

                <div className="Modal">
                    <div className="second_section">
                        <p className="title">{this.props.state}</p>
                        <ul className="ul_modal">
                            <li>Yes</li>
                            <li>No</li>
                         </ul>
                    </div>
                </div>
        )
    }
}


Modal.propTypes = {
    state:propTypes.oneOfType(["Js","Python"])
}


# -----------App.js---------------


function App() {
  return (
    <div className="Boxes_app">
      {/* <Modal message={2}></Modal> */}

      <Modal state="js"></Modal>
    </div>
  );
}

export default App;
